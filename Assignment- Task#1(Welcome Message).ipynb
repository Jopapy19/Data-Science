# %% [markdown]
# #### *Displaying Jupyter notebook (Ananconda3)

# %%
from IPython.display import Image

# %%
Image('D:\PROGRAMMERING !!!\DATA SCIENCE COURSE####\iNEURON iNtellingent CENTER####\iNeuron_Python####\Py4_Course\Assignment\Assignment#1\Install_1.PNG')

# %% [markdown]
# #### * Welcome Message

# %%
a = 'Thank you iNeurone for this opportunity🎁🎓!'
print(a)
# Out:
# Thank you iNeurone for this opportunity🎁🎓!
