# %% [raw]
# In this assignment students have to transform iris data into 3 dimensions
# and plot a 3d chart with transformed dimensions and colour each data
# point with specific class.

# %%
pip install ipython
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
print(__doc__) #Do not need to use it in Jupyter Notebooks. But it useful to crea

import pandas as pd
from sklearn import decomposition
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn import datasets

np.random.seed(5)

#import dataset
iris = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
datasets = pd.read_csv(iris, names=['sepal length','sepal width','petal length','petal width','class'])

#Features specification
features = ['sepal length', 'sepal width', 'petal length', 'petal width']
x = datasets.loc[:, features].values
y = datasets.loc[:,['class']].values

#Applying Principal Component Analysis to the Iris dataset 
pc = PCA(n_components=3, svd_solver='auto')
pComponents = pc.fit_transform(x)
mainDf = pd.DataFrame(data = pComponents, columns = ['Petal length', 'Sepal length', 'Petal width'])
lastDf = pd.concat([principalDf, dataset[['class']]], axis = 1)

## Differents labels for each axis
x_values = lastDf['Petal length']
y_values = lastDf['Sepal length']
z_values = lastDf['Petal width']

# Display figure and Plot the dimensions for interaction.
fig = plt.figure(figsize = (10,10))
ax = fig.add_subplot(111, projection='3d')
ax.set_xlabel('Petal length', fontsize = 12)
ax.set_ylabel('Sepal length', fontsize = 12)
ax.set_zlabel('Petal width', fontsize = 12)
ax.set_title('First 3 PCA directions', fontsize = 15)

targets = ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']
colors = ['g', 'y', 'k']
for target, color in zip(targets,colors):
    indices = lastDf['class'] == target
    ax.scatter(lastDf.loc[indices, 'Petal length']
               , lastDf.loc[indices, 'Sepal length']
               , lastDf.loc[indices, 'Petal width']
               , c = color
               , s = 50)

ax.legend(targets)
ax.grid()
ax.dist = 11
plt.show()
# Out:
# Automatically created module for IPython interactive environment
